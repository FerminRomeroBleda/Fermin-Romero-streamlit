# %%
import streamlit as st
from pickle import load

#CONFIG    
st.set_page_config(
    page_title = "MyModel", #Titulo de la pestaña
    #page_icon = favicon
    layout="wide"
)

#CSS
st.markdown("""
    <style>
        /*Header Nativo*/
        .st-emotion-cache-h4xjwg{
            display: None;
        }
        
        /* Sidebar */
        .st-emotion-cache-1itdyc2 {
            background-color: #333;
            border: 3px;
            border-radius: 10px;
            width: 20%;
            height: 90hv;
            padding: 10px;
            margin: 10 px;
            float:left;
            clear: bottom;
            z-index: 99998;
        }

        /* Footer*/
        .footer {
            position: fixed;
            bottom: 0;
            left: 0;
            width: 100%;
            background-color: #333;
            color: white;
            text-align: center;
            padding: 10px;
            position:fixed;
            clear: left;
            z-index: 9999;  /* Hacer que el footer se muestre por encima del sidebar */
        }
        
        /*Botones*/
        .st-emotion-cache-fm8pe0 {
            padding-top: 5px;
            padding-bottom: 5px;
            padding-left: 10px;
            padding-right: 10px;
            float: left;
            clear: bottom;
        }
        
        st-emotion-cache-lpgk4i {
            padding-top: 5px;
            padding-bottom: 5px;
            padding-left: 10px;
            padding-right: 10px;
            float: right;
            clear: top;
        }
    </style>
""", unsafe_allow_html=True)

st.sidebar.slider("var1")
st.sidebar.slider("var2")
st.sidebar.slider("var3")

st.title("Nombre del modelo.")

predict = st.sidebar.button("predict")
clear = st.sidebar.button("clear")
st.markdown("<div class=\"footer\">Derechos registrados noseque 2025.</div>", unsafe_allow_html=True)
